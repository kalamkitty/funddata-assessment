# %% [markdown]
# ## Exercise 1
#
# Create box plots on a single set of axes for all five experiments in the morley data set.

# %%
# code from Topic 4: Recreating the Wikipedia Box Plot
# https://atlantictu-my.sharepoint.com/personal/ian_mcloughlin_atu_ie/_layouts/15/stream.aspx?id=%2Fpersonal%2Fian%5Fmcloughlin%5Fatu%5Fie%2FDocuments%2Fvideo%2Dlectures%2F2223%2Ffundamentals%5Fdata%5Fanalysis%2F2223%2Ds1%2Dfunddata%2Dw10v01%2Drecreate%2Dwiki%2Dbox%2Dplot%2Emkv&ga=1

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Read in the morley data from data folder.
data = np.genfromtxt('data/morley.csv', skip_header=1, delimiter=',', deletechars='"')

# Remove the first column.
data = data[:,1:]

# %%
# Morley data is created by 5 experiments, each with 20 consecutive runs.

# first experiment row 0-20, ignoring the first column (the headings)
exper_1 = data[:20,1]

exper_2 = data[20:40,1]

exper_3 = data[40:60,1]

exper_4 = data[60:80,1]

exper_5 = data[80:100,1]

# %%
plt.xlabel("Experiment Number")
plt.ylabel("Speed of light")
plt.title("Morley's dataset Boxplot")

#create a box plot for the 5 experiments
plt.boxplot(np.array([exper_1, exper_2, exper_3, exper_4, exper_5]).T);

# %% [markdown]
# ## Exercise 2
#
# Create box plots for all of the numercial variables in Fisher's Iris Data Set.

# %%
df = pd.read_csv ("data/iris.csv", header = None)
df.columns = ["Sepal_length", "Sepal_width", "Petal_length", "Petal_width", "Class"] 
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# https://seaborn.pydata.org/generated/seaborn.boxplot.html - seaborn boxplots
import seaborn as sns

# https://dev.to/thalesbruno/subplotting-with-matplotlib-and-seaborn-5ei8 - subplotting with seaborn
# Organise plots 2 rows x 2 columns. Set figure size
fig, axes = plt.subplots(2,2, figsize= (16,8))

fig.suptitle("Box plots for numerical variables in Fisher's Data Set")

sns.boxplot(y="Sepal_length", x= "Class", data=df, orient='v', ax=axes[0, 0])

sns.boxplot(y="Sepal_width", x= "Class", data=df, orient='v', ax=axes[0, 1])

sns.boxplot(y="Petal_length", x= "Class", data=df, orient='v', ax=axes[1,0])

sns.boxplot(y="Petal_width", x= "Class", data=df, orient='v', ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Petal_width'>

# %% [markdown]
# ## Exercise 3
#
# Adapt the below code and plots so that the overall plot is inversely proportional and the individual groups are directly proportional.

# %%
# Code from Topic 4: Simpson's Paradox
# https://atlantictu-my.sharepoint.com/personal/ian_mcloughlin_atu_ie/_layouts/15/stream.aspx?id=%2Fpersonal%2Fian%5Fmcloughlin%5Fatu%5Fie%2FDocuments%2Fvideo%2Dlectures%2F2223%2Ffundamentals%5Fdata%5Fanalysis%2F2223%2Ds1%2Dfunddata%2Dw10v03%2Dsimpson%2Emkv&ga=1

# Create series of x vectors
xs = np.array ([np.linspace (i, i + 2.0, 20) for i in range(10)])

# Create a corresponding series of y vectors.
ys = np.array ([-1.0 * xs[i] + 2 * i for i in range(len(xs))])

# Add some noise.
ys = ys + np.random.normal (0.0, 1.0, ys.shape)

# Create global list of x and y values.
x = xs.flatten()
y = ys.flatten()

# Plot.
plt.plot(x, y, '.');

# %%
# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    # Plot this category.
    plt.plot(xs[i], ys[i], '.')
    # Fit line to category.
    m, c = np.polyfit(xs[i], ys[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');

# %%
# https://blog.udemy.com/inverse-proportion/  

xx = np.array ([np.linspace (i, i + 2.0, 20) for i in range(10)])

# Create a corresponding series of y vectors.
yx = np.array ([-1.0 * xs[i] + 2 * i for i in range(len(xs))])

# Add some noise, added minus sign infront of y vectors to make then negative
yx = -yx + np.random.normal (0.0, 1.0, yx.shape)

# Create global list of x and y values.
x = xx.flatten()
y = yx.flatten()

# Plot.
plt.plot(x, y, '.');

for i in range(len(xx)):
    # Plot this category.
    plt.plot(xx[i], yx[i], '.')
    # Fit line to category.
    m, c = np.polyfit(xx[i], yx[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xx[i].min(), xx[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');

# %% [markdown]
# ## References
#
# Dataset - https://r-data.pmagunia.com/dataset/r-dataset-package-datasets-morley
#
# Code - https://atlantictu-my.sharepoint.com/personal/ian_mcloughlin_atu_ie/_layouts/15/stream.aspx?id=%2Fpersonal%2Fian%5Fmcloughlin%5Fatu%5Fie%2FDocuments%2Fvideo%2Dlectures%2F2223%2Ffundamentals%5Fdata%5Fanalysis%2F2223%2Ds1%2Dfunddata%2Dw10v01%2Drecreate%2Dwiki%2Dbox%2Dplot%2Emkv&ga=1
#
# Code - https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# Code - https://dev.to/thalesbruno/subplotting-with-matplotlib-and-seaborn-5ei8
#
# Code - https://atlantictu-my.sharepoint.com/personal/ian_mcloughlin_atu_ie/_layouts/15/stream.aspx?id=%2Fpersonal%2Fian%5Fmcloughlin%5Fatu%5Fie%2FDocuments%2Fvideo%2Dlectures%2F2223%2Ffundamentals%5Fdata%5Fanalysis%2F2223%2Ds1%2Dfunddata%2Dw10v03%2Dsimpson%2Emkv&ga=1
#
# Inversely proportional formula - https://blog.udemy.com/inverse-proportion/
